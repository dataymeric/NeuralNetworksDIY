# %%
# %cd "d:\~Perso\Etudes\DAC\NeuralNetworksDIY\"
# Out:
# d:\~Perso\Etudes\DAC\NeuralNetworksDIY

# %%
import numpy as np
import pandas as pd
from src.linear import Linear
from src.loss import *
from src.activation import TanH, Sigmoid, Softmax
from src.encapsulation import Sequential, Optim
np.random.seed(42)

batch_size = 32
d = 2  # Dim des entrées

X = np.random.random(size=(256, d))
y = np.random.choice([1], size=(256, 1))

net = Sequential(
    Linear(2, 2),
    TanH(),
    Linear(2, 1),
    Sigmoid(),
)

optimizer = Optim(net, CrossEntropyLoss(), eps=1e-1)
lossList = optimizer.SGD(X, y, batch_size, 50, verbose=False)
print(lossList)
pd.Series(lossList).plot()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 1193.62it/s]
# Epoch [1], Loss = 0.1759
# Epoch [2], Loss = 0.0692
# Epoch [3], Loss = 0.0530
# Epoch [4], Loss = 0.0447
# Epoch [5], Loss = 0.0393
# Epoch [6], Loss = 0.0355
# Epoch [7], Loss = 0.0326
# Epoch [8], Loss = 0.0304
# Epoch [9], Loss = 0.0285
# Epoch [10], Loss = 0.0270
# Epoch [11], Loss = 0.0256
# Epoch [12], Loss = 0.0245
# Epoch [13], Loss = 0.0235
# Epoch [14], Loss = 0.0226
# Epoch [15], Loss = 0.0218
# Epoch [16], Loss = 0.0211
# Epoch [17], Loss = 0.0204
# Epoch [18], Loss = 0.0198
# Epoch [19], Loss = 0.0193
# Epoch [20], Loss = 0.0188
# Epoch [21], Loss = 0.0183
# Epoch [22], Loss = 0.0178
# Epoch [23], Loss = 0.0174
# Epoch [24], Loss = 0.0171
# Epoch [25], Loss = 0.0167
# Epoch [26], Loss = 0.0164
# Epoch [27], Loss = 0.0161
# Epoch [28], Loss = 0.0158
# Epoch [29], Loss = 0.0155
# Epoch [30], Loss = 0.0152
# Epoch [31], Loss = 0.0150
# Epoch [32], Loss = 0.0147
# Epoch [33], Loss = 0.0145
# Epoch [34], Loss = 0.0143
# Epoch [35], Loss = 0.0141
# Epoch [36], Loss = 0.0139
# Epoch [37], Loss = 0.0137
# Epoch [38], Loss = 0.0135
# Epoch [39], Loss = 0.0133
# Epoch [40], Loss = 0.0131
# Epoch [41], Loss = 0.0130
# Epoch [42], Loss = 0.0128
# Epoch [43], Loss = 0.0126
# Epoch [44], Loss = 0.0125
# Epoch [45], Loss = 0.0124
# Epoch [46], Loss = 0.0122
# Epoch [47], Loss = 0.0121
# Epoch [48], Loss = 0.0120
# Epoch [49], Loss = 0.0118
# Epoch [50], Loss = 0.0117
# [0.17586348 0.06920521 0.0529522  0.04466963 0.03931157 0.03552456
#  0.03264445 0.03037106 0.02852354 0.02695372 0.02563588 0.02447935
#  0.02347374 0.02258363 0.02178068 0.02105869 0.0203995  0.01980843
#  0.01925759 0.0187533  0.01828083 0.01784602 0.01744472 0.01706242
#  0.0167078  0.0163736  0.01605998 0.01576242 0.01547936 0.01521269
#  0.01495461 0.01471466 0.01448431 0.01426281 0.01405373 0.01385198
#  0.01365667 0.01347343 0.01329537 0.01312338 0.01296023 0.01280022
#  0.01264751 0.01249945 0.01235704 0.0122172  0.01208437 0.01195652
#  0.01183031 0.0117089 ]
# <AxesSubplot:>
