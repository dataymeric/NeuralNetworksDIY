# %%
# %cd "d:\~Perso\Etudes\DAC\NeuralNetworksDIY\"
# Out:
# d:\~Perso\Etudes\DAC\NeuralNetworksDIY

# %%
import numpy as np
import pandas as pd
from src.linear import Linear
from src.losses import MSELoss, CrossEntropyLoss, BinaryCrossEntropy, LogCrossEntropyLoss
from src.non_linear import TanH, Sigmoide, SoftMax
from src.encapsulation import Sequential, Optim
np.random.seed(42)

batch_size = 32
d = 2  # Dim des entrées

X = np.random.random(size=(256, d))
y = np.random.choice([1], size=(256, 1))

net = Sequential(
    Linear(2, 2),
    TanH(),
    Linear(2, 1),
    Sigmoide(),
)

optimizer = Optim(net, CrossEntropyLoss(), eps=1e-1)
lossList = optimizer.SGD(X, y, batch_size, 10)
print(lossList)
pd.Series(lossList).plot()
# Out:
# Epoch 1
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.09597955185682863
# Epoch 2
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.0655489330898068
# Epoch 3
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.0526934911976161
# Epoch 4
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.045187940193585546
# Epoch 5
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.04013174681507416
# Epoch 6
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.03643389536782804
# Epoch 7
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.03358051826103558
# Epoch 8
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.03129388583726993
# Epoch 9
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.029409117069250906
# Epoch 10
# -------------------------------
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# Forward de Linear
# Input : (32, 2)
# Forward de TanH
# Input : (32, 2)
# Forward de Linear
# Input : (32, 2)
# Forward de Sigmoide
# Input : (32, 1)
# Output: (32, 1)
# Shape of loss delta : (32, 1)
# ➡️ Backward de Sigmoide
# Shape of delta : (32, 1)
# Shape of inputs : (32, 1)
# Backward de Sigmoide ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 1)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Backward de TanH
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de TanH ✅
# ➡️ Backward de Linear
# Shape of delta : (32, 2)
# Shape of inputs : (32, 2)
# Backward de Linear ✅
# ➡️ Update parameter de Linear
# ➡️ Update parameter de TanH
# ➡️ Update parameter de Linear
# ➡️ Update parameter de Sigmoide
# loss = 0.027821384891897328
# [0.09597955 0.06554893 0.05269349 0.04518794 0.04013175 0.0364339
#  0.03358052 0.03129389 0.02940912 0.02782138]
# <Axes: >
