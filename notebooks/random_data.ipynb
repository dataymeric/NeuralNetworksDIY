# %%
# %cd "d:\~Perso\Etudes\DAC\NeuralNetworksDIY\"
# Out:
# d:\~Perso\Etudes\DAC\NeuralNetworksDIY

# %%
import numpy as np
import pandas as pd
from src.linear import Linear
from src.losses import *
from src.non_linear import TanH, Sigmoide, Softmax
from src.encapsulation import Sequential, Optim
np.random.seed(42)

batch_size = 32
d = 2  # Dim des entrées

X = np.random.random(size=(256, d))
y = np.random.choice([1], size=(256, 1))

net = Sequential(
    Linear(2, 2),
    TanH(),
    Linear(2, 1),
    Sigmoide(),
)

optimizer = Optim(net, CrossEntropyLoss(), eps=1e-1)
lossList = optimizer.SGD(X, y, batch_size, 50)
print(lossList)
pd.Series(lossList).plot()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 1562.03it/s]
# [0.09597955 0.06554893 0.05269349 0.04518794 0.04013175 0.0364339
#  0.03358052 0.03129389 0.02940912 0.02782138 0.02646046 0.02527731
#  0.02423654 0.02331185 0.02248328 0.02173535 0.02105584 0.02043498
#  0.01986484 0.01933891 0.01885179 0.01839895 0.01797658 0.01758143
#  0.01721071 0.01686202 0.01653326 0.01622263 0.01592853 0.01564954
#  0.01538443 0.01513208 0.01489151 0.01466184 0.01444227 0.01423209
#  0.01403065 0.01383737 0.0136517  0.01347317 0.01330134 0.01313579
#  0.01297615 0.01282209 0.01267329 0.01252946 0.01239032 0.01225564
#  0.01212517 0.0119987 ]
# <Axes: >
